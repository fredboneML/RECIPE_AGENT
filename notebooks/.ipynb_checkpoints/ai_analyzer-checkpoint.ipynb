# %% [markdown]
# # AI - Analyzer

# %%
import pandas as pd

# Specifying the path to our JSON file
json_file_path = '../data/transcriptions (3).json'

# Read the JSON file
df = pd.read_json(json_file_path)

# Print the DataFrame to verify
print(df)
# Out:
#        type version                               comment               name  \
# 0    header   5.2.1  Export to JSON plugin for PHPMyAdmin                NaN
# 1  database     NaN                                   NaN  transcriptions_db
# 2     table     NaN                                   NaN     transcriptions
#
#             database                                               data
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2  transcriptions_db  [{'id': '18531', 'processingdate': '2024-09-24...

# %%
df.columns
# Out:
# Index(['type', 'version', 'comment', 'name', 'database', 'data'], dtype='object')
